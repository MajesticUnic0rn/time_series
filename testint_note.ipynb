# %%
import pandas as pd 
import numpy as np

# %%
train_location ="data/train.csv"
test_location ="data/test.csv"

# %%
input_training = pd.read_csv(train_location,nrows=1)
input_test =pd.read_csv(test_location,nrows=1)

# %%
list(input_training.columns)
# Out:
# ['EffectiveDate',
#  'DRKey',
#  'OnRent',
#  'IHSRentalMarket',
#  'AvgTemp',
#  'AvgPrcp',
#  'OnRent_lag_91',
#  'OnRent_lag_98',
#  'OnRent_lag_105',
#  'OnRent_lag_112',
#  'OnRent_lag_119',
#  'OnRent_lag_126',
#  'OnRent_lag_182',
#  'OnRent_lag_364',
#  'sales_ewm_alpha_095_lag_91',
#  'sales_ewm_alpha_095_lag_98',
#  'sales_ewm_alpha_095_lag_105',
#  'sales_ewm_alpha_095_lag_112',
#  'sales_ewm_alpha_095_lag_180',
#  'sales_ewm_alpha_095_lag_270',
#  'sales_ewm_alpha_095_lag_365',
#  'sales_ewm_alpha_09_lag_91',
#  'sales_ewm_alpha_09_lag_98',
#  'sales_ewm_alpha_09_lag_105',
#  'sales_ewm_alpha_09_lag_112',
#  'sales_ewm_alpha_09_lag_180',
#  'sales_ewm_alpha_09_lag_270',
#  'sales_ewm_alpha_09_lag_365',
#  'sales_ewm_alpha_08_lag_91',
#  'sales_ewm_alpha_08_lag_98',
#  'sales_ewm_alpha_08_lag_105',
#  'sales_ewm_alpha_08_lag_112',
#  'sales_ewm_alpha_08_lag_180',
#  'sales_ewm_alpha_08_lag_270',
#  'sales_ewm_alpha_08_lag_365',
#  'sales_ewm_alpha_07_lag_91',
# ...

# %%
list(input_test.columns)
# Out:
# ['EffectiveDate',
#  'DRKey',
#  'OnRent',
#  'IHSRentalMarket',
#  'AvgTemp',
#  'AvgPrcp',
#  'OnRent_lag_91',
#  'OnRent_lag_98',
#  'OnRent_lag_105',
#  'OnRent_lag_112',
#  'OnRent_lag_119',
#  'OnRent_lag_126',
#  'OnRent_lag_182',
#  'OnRent_lag_364',
#  'sales_ewm_alpha_095_lag_91',
#  'sales_ewm_alpha_095_lag_98',
#  'sales_ewm_alpha_095_lag_105',
#  'sales_ewm_alpha_095_lag_112',
#  'sales_ewm_alpha_095_lag_180',
#  'sales_ewm_alpha_095_lag_270',
#  'sales_ewm_alpha_095_lag_365',
#  'sales_ewm_alpha_09_lag_91',
#  'sales_ewm_alpha_09_lag_98',
#  'sales_ewm_alpha_09_lag_105',
#  'sales_ewm_alpha_09_lag_112',
#  'sales_ewm_alpha_09_lag_180',
#  'sales_ewm_alpha_09_lag_270',
#  'sales_ewm_alpha_09_lag_365',
#  'sales_ewm_alpha_08_lag_91',
#  'sales_ewm_alpha_08_lag_98',
#  'sales_ewm_alpha_08_lag_105',
#  'sales_ewm_alpha_08_lag_112',
#  'sales_ewm_alpha_08_lag_180',
#  'sales_ewm_alpha_08_lag_270',
#  'sales_ewm_alpha_08_lag_365',
#  'sales_ewm_alpha_07_lag_91',
# ...

# %%
input_test.head()
# Out:
#   EffectiveDate     DRKey  OnRent  IHSRentalMarket    AvgTemp  AvgPrcp  \
# 0    2019-05-21  407-2110     104         3.145177  77.022222      0.0
#
#    OnRent_lag_91  OnRent_lag_98  OnRent_lag_105  OnRent_lag_112  ...  \
# 0           74.0           83.0            83.0            94.0  ...
#
#    RegionName_REGION04  RegionName_REGION05  RegionName_REGION06  \
# 0                    1                    0                    0
#
#    RegionName_REGION07  RegionName_REGION08  RegionName_REGION09  \
# 0                    0                    0                    0
#
#    RegionName_REGION10  RegionName_REGION11  RegionName_REGION12  \
# 0                    0                    0                    0
#
#    RegionName_REGION14
# 0                    0
#
# [1 rows x 339 columns]

# %%
input_training.head()
# Out:
#   EffectiveDate     DRKey  OnRent  IHSRentalMarket    AvgTemp   AvgPrcp  \
# 0    2016-01-01  103-1060       0         1.982141  33.633333  0.001666
#
#    OnRent_lag_91  OnRent_lag_98  OnRent_lag_105  OnRent_lag_112  ...  \
# 0            2.0            2.0             0.0             1.0  ...
#
#    RegionName_REGION04  RegionName_REGION05  RegionName_REGION06  \
# 0                    0                    0                    0
#
#    RegionName_REGION07  RegionName_REGION08  RegionName_REGION09  \
# 0                    0                    0                    0
#
#    RegionName_REGION10  RegionName_REGION11  RegionName_REGION12  \
# 0                    0                    0                    0
#
#    RegionName_REGION14
# 0                    0
#
# [1 rows x 339 columns]
